# %% [markdown]
# #### 模块
#     一个python文件为一个模块
# #### 包
#     一个目录并且包含__init__.py为包
# #### 安装第三方包
#     pip3 install [包名]

# %%
# 包的导入和使用
# 安装matplotlib包，$ pip3 install matplotlib

import matplotlib.pyplot as plt

# 1.创建画布
plt.figure(figsize=(5,2), dpi=100)

# 2.绘制图像
plt.plot([1, 2, 3, 4, 5, 6, 7], [10, 15, 13, 18, 16, 20, 10])

# 3.图像显示
plt.show()
